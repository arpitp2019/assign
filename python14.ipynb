# %%
'''1. RGBA stands for: Red, Green, Blue, and Alpha. It is a color model that 
includes an additional alpha channel to represent transparency or opacity.



2. To get the RGBA value of an image using the Pillow module: You can use the
getpixel() method on an Image object to retrieve the RGBA value of a specific pixel. For example:

'''
from PIL import Image

# Open an image
image = Image.open("example.png")

# Get the RGBA value at coordinates (x, y)
rgba_value = image.getpixel((x, y))


'''3. Box Tuple: In the context of Pillow, a box tuple is a tuple that specifies a rectangular region within an image. It is represented as (left, upper, right, lower), where (left, upper) are the coordinates of the top-left corner of the rectangle, and (right, lower) are the coordinates of the bottom-right corner. The box tuple is used to define regions for various operations, such as cropping or pasting.

4.  To find the width and height of an Image object: You can use the width and height attributes of the Image object, like this:

'''
image = Image.open("example.png")
width = image.width
height = image.height


'''5. Method to Get a 100×100 Image Excluding Lower-Left Quarter: You can use the crop()
method to extract a portion of the image. To get a 100x100 region excluding the lower-left quarter, 
you can do:'''


upper_left = (0, 0)
lower_right = (100, 100)
cropped_image = image.crop((upper_left[0], upper_left[1], lower_right[0], lower_right[1]))


'''6. To save changes to an Image object as an image file: You can use the save() method, 
specifying the filename and file format. For example:


image.save("output.png") 


You can specify the desired file format by providing the appropriate file extension (e.g., ".png", ".jpg").'''

'''7. Module containing Pillow's shape-drawing code: The shape-drawing code in Pillow is found in the Pillow.
ImageDraw module.'''

'''8.  Image objects do not have drawing methods. What kind of object does? How do you get this kind of object? To draw shapes and text on an image, you need to create a drawing object. You can get a drawing object by using the ImageDraw.Draw() method and passing in the Image object as an argument. Here's an example:
'''

from PIL import Image, ImageDraw

image = Image.open("example.png")
draw = ImageDraw.Draw(image)
